# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushmann25bce10347-jpg/The-Knowledge-Vault/blob/main/The_Knowledge_Vault.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#The Knowledge Vault
#By Ayushmann Prakash
questions=[[
    "Where the first olympics games held?", "INDIA", "FRANCE", "GREECE", "JAPAN", 3
]
,
[
    " Which is the largest ocean in the world?", "Pacific ocean","Indian Ocean","Antartic ocean","Atlanta ocean",0
],
[
    "What is the capital of Australia?","Canberra","Delhi","Berlin","None",0
],
[
    "What is the longest river in the world?","Yamuna","Nile","Brahmaputra","Yeki",1
],
[
    "What is the hardest natural substance on Earth?","Gold", "Steel", "Diamond","Quartz",2

],
[
    "Who wrote 'Harry Potter'?","J.R.R. Tolkien", "J.K. Rowling", "Stephen King", "George Orwell",1

],
[
    "What is the capital of France?", "Paris", "London", "Berlin", "Madrid",0

],
[
    "Which planet is known as the Red Planet?","Earth", "Mars", "Jupiter", "Venus",1
],
[
    "Who is known as the Father of the Nation in India?"," Jawaharlal Nehru", " Subhas Chandra Bose", "Mahatma Gandhi", " Bhagat Singh",2
],
[
    "What is the chemical symbol for Oxygen?","O2", "Ox", "O", "Oy",0
],
[
    "Who wrote 'Romeo and Juliet'?"," Charles Dickens", " Jane Austen",  "William Shakespeare", " Mark Twain",2
],
[
    "What is the chemical symbol for water?", "O2", "H", "W","H2O",3
],
[
  "Which animal is known as the \"Ship of the Desert\"?", "Lion", "Camel", "Elephant", "Giraffe",1
],
[
 "What is the process by which plants make their own food?","Respiration","Germination","Photosynthesis","Transpiration",2
],
[
  "How many colors are in a rainbow?" ,"Six","Eight","Five","Seven",3
],
[
    "Which of the following planets is not a gas giant?","Uranus","Jupiter","Mars","Saturn",2
]
]
levels=[1000,2000,3000,5000,10000,20000,40000,80000,160000,320000,640000,1250000,2500000,5000000,10000000]
money=0
for i in range (0,len(questions)):
  question=questions[i]
  print(f"Question for Rs.{levels[i]}")
  print(f"a.{question[1]}       b.{question[2]}")
  print(f"c.{question[3]}       d.{question[4]}")
  reply=int(input("Enter your answer(1,4)"))
  if (reply==question[-1]):
    print(f"Correct answer,you have won Rs.{levels[i]}")
    if(i==4):
      print("You have won Rs.10000")
  elif (i==9):
        print("You have won Rs.320000")
  elif(i==14):
        print("You have won Rs.10000000")
  else:
      print(f"Wrong answer!")
      break
# Out:
# Question for Rs.1000
# a.INDIA       b.FRANCE
# c.GREECE       d.JAPAN
# Enter your answer(1,4)3
# Correct answer,you have won Rs.1000
# Question for Rs.2000
# a.Pacific ocean       b.Indian Ocean
# c.Antartic ocean       d.Atlanta ocean
# Enter your answer(1,4)0
# Correct answer,you have won Rs.2000
# Question for Rs.3000
# a.Canberra       b.Delhi
# c.Berlin       d.None
# Enter your answer(1,4)0
# Correct answer,you have won Rs.3000
# Question for Rs.5000
# a.Yamuna       b.Nile
# c.Brahmaputra       d.Yeki
# Enter your answer(1,4)1
# Correct answer,you have won Rs.5000
# Question for Rs.10000
# a.Gold       b.Steel
# c.Diamond       d.Quartz
# Enter your answer(1,4)2
# Correct answer,you have won Rs.10000
# You have won Rs.10000
# Question for Rs.20000
# a.J.R.R. Tolkien       b.J.K. Rowling
# c.Stephen King       d.George Orwell
# Enter your answer(1,4)3
# Wrong answer!
